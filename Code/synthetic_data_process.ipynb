# %% [markdown]
# Synthetic Data Processing

# %%
##import necessary variables
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
## read synthetic data using pandas
data = pd.read_csv('generated_samples.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   TemP (K)             100000 non-null  float64
#  1   Time (min)           100000 non-null  float64
#  2   PS (mm)              100000 non-null  float64
#  3   BET (m2/g)           100000 non-null  float64
#  4   PV (cm3)             100000 non-null  float64
#  5   C (wt.%)             100000 non-null  float64
#  6   H  (wt.%)            100000 non-null  float64
#  7   N  (wt.%)            100000 non-null  float64
#  8   O  (wt.%)            100000 non-null  float64
#  9   Qm (mg/g)            100000 non-null  float64
#  10  TP_Benzocaine        100000 non-null  float64
#  11  TP_Ciprofloxacin     100000 non-null  float64
#  12  TP_Citalopram        100000 non-null  float64
#  13  TP_Diclofenac        100000 non-null  float64
#  14  TP_Dimetridazole     100000 non-null  float64
#  15  TP_Floxentine        100000 non-null  float64
#  16  TP_Metronidazole     100000 non-null  float64
#  17  TP_Nitroimidazole    100000 non-null  float64
#  18  TP_Norfloxacin       100000 non-null  float64
#  19  TP_Oxytetracycline   100000 non-null  float64
#  20  TP_Oxytetracycline   100000 non-null  float64
#  21  TP_Salicylic acid    100000 non-null  float64
#  22  TP_Sulfadiazine      100000 non-null  float64
#  23  TP_Sulfamethoxazole  100000 non-null  float64
#  24  TP_Tetracycline      100000 non-null  float64
#  25  TP_Triclosan         100000 non-null  float64
#  26  TP_ibuprofen         100000 non-null  float64
#  27  TP_sulfamethazine    100000 non-null  float64
# dtypes: float64(28)
# memory usage: 21.4 MB

# %%
# print first 5 rows
data.head()
# Out:
#     TemP (K)  Time (min)    PS (mm)  BET (m2/g)  PV (cm3)   C (wt.%)  \
# 0  698.72690   41.426437   9.023187  -48.115734  0.249153  42.152912
# 1  470.83698   58.439590   8.936554   59.169704  0.016805  45.507927
# 2  454.72098   38.041320  10.946335   22.136755  0.158861  43.979450
# 3  443.34985  139.319400  13.040448  304.560300  0.321415  38.201336
# 4  679.47460  123.031680  10.003470  -23.197474  0.257596  42.609512
#
#    H  (wt.%)  N  (wt.%)  O  (wt.%)  Qm (mg/g)  ...  TP_Norfloxacin  \
# 0   0.576135   0.046908   5.924716   5.326881  ...        0.017257
# 1   0.357714   1.481977  17.479969  69.307520  ...       -0.041909
# 2   0.451820   4.240861  10.044512  47.410748  ...       -0.001456
# 3   0.456296   2.317892  12.404156  36.724180  ...       -0.165654
# 4   1.169315   1.611443   7.204152  66.727940  ...       -0.096341
#
#    TP_Oxytetracycline  TP_Oxytetracycline   TP_Salicylic acid  \
# 0            0.072861            -0.070362          -0.065879
# 1            0.119286             0.005943          -0.037580
# 2            0.121266            -0.013221           0.114658
# 3            0.083135             0.067530          -0.002301
# 4           -0.035783            -0.007817          -0.070565
#
#    TP_Sulfadiazine  TP_Sulfamethoxazole  TP_Tetracycline  TP_Triclosan  \
# 0        -0.082032             0.070146        -0.064403      0.192970
# 1        -0.052150            -0.054986         0.117819      0.164187
# 2        -0.053196            -0.067730         0.313062      0.165599
# 3         0.059933            -0.194165         0.185696      0.205001
# 4        -0.078142            -0.151258         0.521432      0.221887
#
#    TP_ibuprofen  TP_sulfamethazine
# 0      0.433743            0.228728
# 1      0.371218            0.369029
# 2      0.238351           -0.099984
# 3      0.407172            0.100052
# 4      0.348172            0.257137
#
# [5 rows x 28 columns]

# %%
##see the columns
data.columns
# Out:
# Index(['TemP (K)', 'Time (min)', 'PS (mm)', 'BET (m2/g)', 'PV (cm3)',
#        'C (wt.%)', 'H  (wt.%)', 'N  (wt.%)', 'O  (wt.%)', 'Qm (mg/g)',
#        'TP_Benzocaine', 'TP_Ciprofloxacin', 'TP_Citalopram', 'TP_Diclofenac ',
#        'TP_Dimetridazole', 'TP_Floxentine', 'TP_Metronidazole',
#        'TP_Nitroimidazole', 'TP_Norfloxacin', 'TP_Oxytetracycline',
#        'TP_Oxytetracycline ', 'TP_Salicylic acid', 'TP_Sulfadiazine',
#        'TP_Sulfamethoxazole', 'TP_Tetracycline', 'TP_Triclosan',
#        'TP_ibuprofen', 'TP_sulfamethazine '],
#       dtype='object')

# %%
##only select columns that has numeric data type
columns = ['TemP (K)', 'Time (min)', 'PS (mm)', 'BET (m2/g)', 'PV (cm3)',
       'C (wt.%)', 'H  (wt.%)', 'N  (wt.%)', 'O  (wt.%)', 'Qm (mg/g)']

# %%
## Let's only keep positive values since these values are supposed to be positive
data_clean = data[data['TemP (K)']> 0]
data_clean = data[data['Time (min)']>0]
data_clean = data[data['PS (mm)']>0]
data_clean = data[data['BET (m2/g)']>0]
data_clean = data[data['PV (cm3)']>0]
data_clean = data[data['C (wt.%)']>0]
data_clean = data[data['H  (wt.%)']>0]
data_clean = data[data['N  (wt.%)']>0]
data_clean = data[data['O  (wt.%)']>0]
data_clean = data[data['Qm (mg/g)']>0]

# %%
data_clean.head()
# Out:
#     TemP (K)  Time (min)    PS (mm)  BET (m2/g)  PV (cm3)   C (wt.%)  \
# 0  698.72690   41.426437   9.023187  -48.115734  0.249153  42.152912
# 1  470.83698   58.439590   8.936554   59.169704  0.016805  45.507927
# 2  454.72098   38.041320  10.946335   22.136755  0.158861  43.979450
# 3  443.34985  139.319400  13.040448  304.560300  0.321415  38.201336
# 4  679.47460  123.031680  10.003470  -23.197474  0.257596  42.609512
#
#    H  (wt.%)  N  (wt.%)  O  (wt.%)  Qm (mg/g)  ...  TP_Norfloxacin  \
# 0   0.576135   0.046908   5.924716   5.326881  ...        0.017257
# 1   0.357714   1.481977  17.479969  69.307520  ...       -0.041909
# 2   0.451820   4.240861  10.044512  47.410748  ...       -0.001456
# 3   0.456296   2.317892  12.404156  36.724180  ...       -0.165654
# 4   1.169315   1.611443   7.204152  66.727940  ...       -0.096341
#
#    TP_Oxytetracycline  TP_Oxytetracycline   TP_Salicylic acid  \
# 0            0.072861            -0.070362          -0.065879
# 1            0.119286             0.005943          -0.037580
# 2            0.121266            -0.013221           0.114658
# 3            0.083135             0.067530          -0.002301
# 4           -0.035783            -0.007817          -0.070565
#
#    TP_Sulfadiazine  TP_Sulfamethoxazole  TP_Tetracycline  TP_Triclosan  \
# 0        -0.082032             0.070146        -0.064403      0.192970
# 1        -0.052150            -0.054986         0.117819      0.164187
# 2        -0.053196            -0.067730         0.313062      0.165599
# 3         0.059933            -0.194165         0.185696      0.205001
# 4        -0.078142            -0.151258         0.521432      0.221887
#
#    TP_ibuprofen  TP_sulfamethazine
# 0      0.433743            0.228728
# 1      0.371218            0.369029
# 2      0.238351           -0.099984
# 3      0.407172            0.100052
# 4      0.348172            0.257137
#
# [5 rows x 28 columns]

# %%
## another dataframe just for numerical columns
first_df = data_clean[columns]

# %%
##Let's select columns that have non-numeric values and supposed to be binary
tp_col = ['TP_Benzocaine', 'TP_Ciprofloxacin', 'TP_Citalopram', 'TP_Diclofenac ',
       'TP_Dimetridazole', 'TP_Floxentine', 'TP_Metronidazole',
       'TP_Nitroimidazole', 'TP_Norfloxacin', 'TP_Oxytetracycline',
       'TP_Oxytetracycline ', 'TP_Salicylic acid', 'TP_Sulfadiazine',
       'TP_Sulfamethoxazole', 'TP_Tetracycline', 'TP_Triclosan',
       'TP_ibuprofen', 'TP_sulfamethazine ']

# %%
# one dataframe for one hot encoded variables
tp_data = data_clean[tp_col]
tp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87424 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TP_Benzocaine        87424 non-null  float64
#  1   TP_Ciprofloxacin     87424 non-null  float64
#  2   TP_Citalopram        87424 non-null  float64
#  3   TP_Diclofenac        87424 non-null  float64
#  4   TP_Dimetridazole     87424 non-null  float64
#  5   TP_Floxentine        87424 non-null  float64
#  6   TP_Metronidazole     87424 non-null  float64
#  7   TP_Nitroimidazole    87424 non-null  float64
#  8   TP_Norfloxacin       87424 non-null  float64
#  9   TP_Oxytetracycline   87424 non-null  float64
#  10  TP_Oxytetracycline   87424 non-null  float64
#  11  TP_Salicylic acid    87424 non-null  float64
#  12  TP_Sulfadiazine      87424 non-null  float64
#  13  TP_Sulfamethoxazole  87424 non-null  float64
#  14  TP_Tetracycline      87424 non-null  float64
#  15  TP_Triclosan         87424 non-null  float64
#  16  TP_ibuprofen         87424 non-null  float64
#  17  TP_sulfamethazine    87424 non-null  float64
# dtypes: float64(18)
# memory usage: 12.7 MB

# %%
# let's create a dataframe sime size as our synthetic data with only with 0's
df_binary = pd.DataFrame(0, index=tp_data.index, columns=tp_data.columns)

# Find the column with the maximum value for each row
max_cols = tp_data.idxmax(axis=1)

# Set the maximum value to 1 for each row in the corresponding column
for i, col in enumerate(max_cols):
    df_binary.at[i, col] = 1

# %%
##concat this new dataframe with with numeric dataframe
processed_data = pd.concat([first_df, df_binary], join = 'inner', axis=1)

# %%
processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87424 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TemP (K)             87424 non-null  float64
#  1   Time (min)           87424 non-null  float64
#  2   PS (mm)              87424 non-null  float64
#  3   BET (m2/g)           87424 non-null  float64
#  4   PV (cm3)             87424 non-null  float64
#  5   C (wt.%)             87424 non-null  float64
#  6   H  (wt.%)            87424 non-null  float64
#  7   N  (wt.%)            87424 non-null  float64
#  8   O  (wt.%)            87424 non-null  float64
#  9   Qm (mg/g)            87424 non-null  float64
#  10  TP_Benzocaine        87424 non-null  float64
#  11  TP_Ciprofloxacin     87424 non-null  float64
#  12  TP_Citalopram        87424 non-null  float64
#  13  TP_Diclofenac        87424 non-null  float64
#  14  TP_Dimetridazole     87424 non-null  float64
#  15  TP_Floxentine        87424 non-null  float64
#  16  TP_Metronidazole     87424 non-null  float64
#  17  TP_Nitroimidazole    87424 non-null  float64
#  18  TP_Norfloxacin       87424 non-null  float64
#  19  TP_Oxytetracycline   87424 non-null  float64
#  20  TP_Oxytetracycline   87424 non-null  float64
#  21  TP_Salicylic acid    87424 non-null  float64
#  22  TP_Sulfadiazine      87424 non-null  float64
#  23  TP_Sulfamethoxazole  87424 non-null  float64
#  24  TP_Tetracycline      87424 non-null  float64
#  25  TP_Triclosan         87424 non-null  float64
#  26  TP_ibuprofen         87424 non-null  float64
#  27  TP_sulfamethazine    87424 non-null  float64
# dtypes: float64(28)
# memory usage: 19.3 MB

# %%
##not necessary but we did sort dataframe based on target variable
df_sorted =processed_data.sort_values(by = 'Qm (mg/g)')

# %%
##Box plot for the entire dataframe
df_sorted[columns].plot(kind='box',figsize=(12,6),subplots=True, layout = (2,5))
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.suptitle('Boxplot for each features for synthetic data', fontsize=16)
plt.show()
plt.show()

# %%
##Since we have generated much more data than our requirements and it has computation cost we decided to
# take 5 percent of the dataset by taking random sample.
sampled_df = df_sorted.sample(frac=0.05)
sampled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4371 entries, 94371 to 87007
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TemP (K)             4371 non-null   float64
#  1   Time (min)           4371 non-null   float64
#  2   PS (mm)              4371 non-null   float64
#  3   BET (m2/g)           4371 non-null   float64
#  4   PV (cm3)             4371 non-null   float64
#  5   C (wt.%)             4371 non-null   float64
#  6   H  (wt.%)            4371 non-null   float64
#  7   N  (wt.%)            4371 non-null   float64
#  8   O  (wt.%)            4371 non-null   float64
#  9   Qm (mg/g)            4371 non-null   float64
#  10  TP_Benzocaine        4371 non-null   float64
#  11  TP_Ciprofloxacin     4371 non-null   float64
#  12  TP_Citalopram        4371 non-null   float64
#  13  TP_Diclofenac        4371 non-null   float64
#  14  TP_Dimetridazole     4371 non-null   float64
#  15  TP_Floxentine        4371 non-null   float64
#  16  TP_Metronidazole     4371 non-null   float64
#  17  TP_Nitroimidazole    4371 non-null   float64
#  18  TP_Norfloxacin       4371 non-null   float64
#  19  TP_Oxytetracycline   4371 non-null   float64
#  20  TP_Oxytetracycline   4371 non-null   float64
#  21  TP_Salicylic acid    4371 non-null   float64
#  22  TP_Sulfadiazine      4371 non-null   float64
#  23  TP_Sulfamethoxazole  4371 non-null   float64
#  24  TP_Tetracycline      4371 non-null   float64
#  25  TP_Triclosan         4371 non-null   float64
#  26  TP_ibuprofen         4371 non-null   float64
#  27  TP_sulfamethazine    4371 non-null   float64
# dtypes: float64(28)
# memory usage: 990.3 KB

# %%
#write the dagta as csv file
sampled_df.to_csv('synthetic_data.csv', index = False)

# %%
n_columns = 10

# Read the Actual data
Actual_data = pd.read_excel('updated_DATASET.xlsx', engine="openpyxl", usecols=range(n_columns))

# Read the synthetic data
synthetic_data = pd.read_csv('synthetic_data.csv', usecols=range(n_columns))

# %%
# Create a column to indicate the type of data
Actual_data['Type'] = 'Actual'
synthetic_data['Type'] = 'Synthetic'

# Concatenate the two datasets
combined_data = pd.concat([Actual_data, synthetic_data])

# Melt the data for easier plotting
melted_data = pd.melt(combined_data, id_vars='Type', var_name='Column', value_name='Value')

# %%
import seaborn as sns
# Set the aesthetic style of the plots
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

# Create a grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))  # Adjust the layout according to the number of columns
axes = axes.flatten()  # Flatten the array of axes to easily index them

# Plot each column in a separate subplot
for i, column in enumerate(melted_data['Column'].unique()):
    sns.boxplot(
        x='Type',
        y='Value',
        data=melted_data[melted_data['Column'] == column],
        ax=axes[i],
        notch=True
    )
    axes[i].set_title(column, fontsize=12)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Value' if i % 5 == 0 else '')  # Display y-axis label only on the leftmost plots for clarity
    axes[i].tick_params(labelsize=10)

# Adjust the layout
plt.tight_layout(pad=2.0)

# Show the plot
